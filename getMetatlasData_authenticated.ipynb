# %% [markdown]
# This notbook requests images for a given m/z range and shows a flux image

# %%
# %pylab inline
# %config InlineBackend.figure_format = 'svg' 
from pylab import *
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import time
import sys
import requests, json
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Run the next block once to setup the csrf token for subsequent calls to the server.

# %%
authURL = 'https://metatlas.nersc.gov/client/login/'
userID = 'bpb'
userPassword = ''

client = requests.Session()
# Retrieve the CSRF token first
client.get(authURL)  # sets cookie
csrftoken = client.cookies['csrftoken']
login_data = dict(username=userID, password=userPassword, csrfmiddlewaretoken=csrftoken, next='/')
r = client.post(authURL, data=login_data, headers=dict(Referer=authURL))

# %%
url = 'https://metatlas.nersc.gov/api/experiment'
r = client.get(url,data=login_data)
experiments = json.loads(r.content)
print experiments
myID = filter( lambda x: x[u'name']=='Soil_Particle_Metabolite_Interactions', experiments )[0][u'_id']
# sites = dict( (d['site'],d) for d in data )
# ids = dict( (d['id'],d] for d in data )
# any(d[u'name'] == 'Soil_Particle' for d in experiments)
# myID = experiments[3][u'_id']
# print myID
# Out:
# [{u'dict_ids': [], u'description': u'', u'creator': u'bpb', u'last_update': u'2014-08-28 03:10:06.059000', u'_id': u'53e269a1d4a4c9f6befdd3fd', u'name': u'20140707_SJ_WoM_1p0'}, {u'dict_ids': [], u'description': u'', u'creator': u'bpb', u'last_update': u'2014-08-28 03:10:08.236000', u'_id': u'53e269a3d4a4c9f6befdd3ff', u'name': u'CHCl3MeOHH2O_C1855_ACNIPAH2O_QTOF6520_KBL'}, {u'dict_ids': [], u'description': u'', u'creator': u'bpb', u'last_update': u'2014-08-28 03:10:08.273000', u'_id': u'53e269a4d4a4c9f6befdd400', u'name': u'MeOH_ZH70_ACNH2O_QTOF6520_RB'}, {u'dict_ids': [u'53ecfbf67626404d893f94bb', u'53ed0a027626404d833a6c19', u'53eea4a67626404d7f755f77', u'53fe42697626400f82e912b0'], u'description': u'', u'creator': u'bpb', u'last_update': u'2014-08-28 03:10:07.962000', u'_id': u'53e269a2d4a4c9f6befdd3fe', u'name': u'20140707_SJ_WoM_32bitConvert'}, {u'dict_ids': [], u'description': u'', u'creator': u'bpb', u'last_update': u'2014-08-28 03:10:08.294000', u'_id': u'53fe9ca408dbab407393fe19', u'name': u'Soil_Particle_Metabolite_Interactions'}]

# %%
url = 'https://metatlas.nersc.gov/api/experiment/%s' % myID
r = client.get(url,data=login_data)
files = json.loads(r.content)
print files
myFilename = '/global/project/projectdirs/metatlas/original_data/bpb/Soil_Particle_Metabolite_Interactions/140808_1_RCH2_pos.mzML'
myMatch = filter( lambda x: x[u'in_file']==myFilename, files[u'runs'] )[0][u'_id']
myMatch = filter( lambda x: x[u'in_file']==myFilename, files[u'runs'] )[0][u'_id']
myArray = myMatch[u'array_name']
myFid = myMatch[u'file_id']

# print files
# print files.keys()
# print files[u'runs'][-1]
# myArray = files[u'runs'][-1][u'_id'][u'array_name']
# myFid = files[u'runs'][-1][u'_id'][u'file_id']
# print myArray
# print myFid
# print experiments[3]
# myID = experiments[3][u'_id']
# print myID
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-52d20c94f14c> in <module>()
#       4 print files
#       5 myFilename = '/global/project/projectdirs/metatlas/original_data/bpb/Soil_Particle_Metabolite_Interactions/140808_1_RCH2_pos.mzML'
# ----> 6 myMatch = filter( lambda x: x[u'in_file'].find(myFilename) > 0, files[u'runs'] )[0][u'_id']
#       7 myArray = myMatch[u'array_name']
#       8 myFid = myMatch[u'file_id']
#
# IndexError: list index out of range
# {u'runs': [{u'upload_date': u'2014-08-28 16:14:41.181000', u'out_file': u'/global/project/projectdirs/metatlas/loading/tmp1TiSC5', u'creator': u'bpb', u'creation_date': u'2014-08-28 03:06:13.405000', u'experiment': u'53fe9ca408dbab407393fe19', u'in_file': u'/global/project/projectdirs/metatlas/original_data/bpb/Soil_Particle_Metabolite_Interactions/140808_8_64mg_fhy_neg.mzML', u'uploaded_by': u'bpb', u'_id': {u'array_name': u'lcms_test_1', u'file_id': 9211}, u'pending': 0}, {u'upload_date': u'2014-08-28 16:14:59.380000', u'out_file': u'/global/project/projectdirs/metatlas/loading/tmpoM6f64', u'creator': u'bpb', u'creation_date': u'2014-08-28 03:06:12.878000', u'experiment': u'53fe9ca408dbab407393fe19', u'in_file': u'/global/project/projectdirs/metatlas/original_data/bpb/Soil_Particle_Metabolite_Interactions/140808_1_RCH2_neg.mzML', u'uploaded_by': u'bpb', u'_id': {u'array_name': u'lcms_test_1', u'file_id': 9209}, u'pending': 0}, {u'upload_date': u'2014-08-28 16:15:31.206000', u'out_file': u'/global/project/projectdirs/metatlas/loading/tmpbBeMhb', u'creator': u'bpb', u'creation_date': u'2014-08-28 03:06:13.411000', u'experiment': u'53fe9ca408dbab407393fe19', u'in_file': u'/global/project/projectdirs/metatlas/original_data/bpb/Soil_Particle_Metabolite_Interactions/140808_8_64mg_fhy_pos.mzML', u'uploaded_by': u'bpb', u'_id': {u'array_name': u'lcms_test_1', u'file_id': 9212}, u'pending': 0}, {u'upload_date': u'2014-08-28 16:15:54.007000', u'out_file': u'/global/project/projectdirs/metatlas/loading/tmpH3UtPm', u'creator': u'bpb', u'creation_date': u'2014-08-28 03:06:12.884000', u'experiment': u'53fe9ca408dbab407393fe19', u'in_file': u'/global/project/projectdirs/metatlas/original_data/bpb/Soil_Particle_Metabolite_Interactions/140808_1_RCH2_pos.mzML', u'uploaded_by': u'bpb', u'_id': {u'array_name': u'lcms_test_1', u'file_id': 9210}, u'pending': 0}], u'dict_ids': [], u'description': u'', u'creator': u'bpb', u'last_update': u'2014-08-28 03:10:08.294000', u'_id': u'53fe9ca408dbab407393fe19', u'name': u'Soil_Particle_Metabolite_Interactions'}

# %% [markdown]
# Run the next block to get a chromatogram

# %%
payload = {'L':1,'P':1,'arrayname':myArray,'fileid':myFid,
           'max_mz':132.10253650938,'min_mz':132.10121549062,
           'nsteps':1436,'queryType':'XICofFile'}
url = 'https://metatlas.nersc.gov/api/run'
r = client.get(url,params=payload,data=login_data)
data = np.asarray(json.loads(r.content))

# %% [markdown]
# Get the TIC for a file!!!!

# %%
payload = {'L':1,'P':1,'arrayname':myArray,'fileid':myFid,
           'max_mz':10000,'min_mz':1,
           'nsteps':20000,'queryType':'XICofFile'}
url = 'https://metatlas.nersc.gov/api/run'
r = client.get(url,params=payload,data=login_data)
data = np.asarray(json.loads(r.content))

# %%
print data.shape
print len(np.unique(data[:,0]))
# Out:
# (1436, 2)
# 1436

# %%
# idx = np.argwhere( data[:,0] > 10  and data[:,0] < 20 )
idx = np.argwhere( np.abs( data[:,0] - 13.25 ) < .5 )

# %%
plot(data[:,0],data[:,1])
# xlim([5,20])
# print sum(data[idx,1])
